# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import xarray
import glob

# %%
path = '/jet/home/xjliu/Amazon_exp/Tanguro201401/'
with xarray.open_dataset(path+'wrfout_d01_2014-01-01_00:00:00',decode_times=True,
                         mask_and_scale='True') as ds:
    lats = ds['XLAT'][0,5:-5,5:-5]
    lons = ds['XLONG'][0,5:-5,5:-5]
    znu  = ds['ZNU'][0,:]

# %% [markdown]
# ## Concatente variables and Check whether reach equilibrium

# %%
path = '/jet/home/xjliu/Amazon_exp/Tanguro201401/'
files = sorted(glob.glob(path+'3Dfields_d01_2014-01-*00:00:00'))

with xarray.open_dataset(files[0],decode_times=True,
                         mask_and_scale='True') as ds:
        Uall = ds['U'][:,:,5:-5,5:-5]
        Vall = ds['V'][:,:,5:-5,5:-5]
        Tall = ds['T'][:,:,5:-5,5:-5]
        T2all = ds['T2'][:,5:-5,5:-5]

for ii,filename in enumerate(files[1:15]):
    with xarray.open_dataset(filename,decode_times=True,
                         mask_and_scale='True') as ds:
        Uall = xarray.concat([Uall,ds['U'][:,:,5:-5,5:-5]],dim='Time')
        Vall = xarray.concat([Vall,ds['V'][:,:,5:-5,5:-5]],dim='Time')
        Tall = xarray.concat([Tall,ds['T'][:,:,5:-5,5:-5]],dim='Time')
        T2all = xarray.concat([T2all,ds['T2'][:,5:-5,5:-5]],dim='Time')
    print(Uall.shape,filename)

## concatenate 01-22-00:00
with xarray.open_dataset(path+'3Dfields_d01_2014-01-22_00:00:00',decode_times=True,
                         mask_and_scale='True') as ds:
    Uall = xarray.concat([Uall,ds['U'][0,:,5:-5,5:-5]],dim='Time')
    Vall = xarray.concat([Vall,ds['V'][0,:,5:-5,5:-5]],dim='Time')
    Tall = xarray.concat([Tall,ds['T'][0,:,5:-5,5:-5]],dim='Time')
    T2all = xarray.concat([T2all,ds['T2'][0,5:-5,5:-5]],dim='Time')
    print(Uall.shape,filename)
    
## concatenate the rest of files, starting from 01:00:00
files = sorted(glob.glob(path+'3Dfields_d01_2014-01-*01:00:00'))
for filename in files[:5]:       
    with xarray.open_dataset(filename,decode_times=True,
                         mask_and_scale='True') as ds:
        #Uall = xarray.concat([Uall,ds['U'][:,:,5:-5,5:-5]],dim='Time')
        #Vall = xarray.concat([Vall,ds['V'][:,:,5:-5,5:-5]],dim='Time')
        #Tall = xarray.concat([Tall,ds['T'][:,:,5:-5,5:-5]],dim='Time')
        #T2all = xarray.concat([T2all,ds['T2'][:,5:-5,5:-5]],dim='Time')
        print('hello')
    print(Uall.shape,filename)
# Out:
# (48, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-02_00:00:00
# (72, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-03_00:00:00
# (96, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-04_00:00:00
# (120, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-05_00:00:00
# (144, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-06_00:00:00
# (168, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-07_00:00:00
# (192, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-08_00:00:00
# (216, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-09_00:00:00
# (240, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-10_00:00:00
# (264, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-11_00:00:00
# (288, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-12_00:00:00
# (312, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-13_00:00:00
# (336, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-14_00:00:00
# (360, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-15_00:00:00
# (361, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201401_alltrees/3Dfields_d01_2014-01-15_00:00:00

# %% [markdown]
# ### Plot the height-time section of U

# %%
weights = np.cos(np.deg2rad(lats))
weights.name = "weights"
weights

#Uall_weighted = Uall.weighted(weights)
#Uall_weighted.mean()
#Uall_weighted.mean((("west_east", "south_north")))
Umean = Uall.mean(("west_east_stag", "south_north"))
T2mean = T2all.mean(("west_east", "south_north"))
Vmean = Vall.mean(("west_east", "south_north_stag"))
Tmean = Tall.mean(("west_east", "south_north"))

# %%
fig,axes = plt.subplots(2,2,figsize=(12,8),sharex=True)
axes = axes.ravel()
axes[3].plot(T2mean[:].Time/24,T2mean[:]-273.15)
axes[3].set_xlabel('Time [Day]')
#plt.ylabel('Level')
#plt.gca().invert_yaxis()

im0 = axes[0].contourf(Umean[:].Time/24,znu,Umean[:].transpose(),
             levels=np.linspace(-20,20,11),
             extend='both',
            cmap='PiYG')

im1 = axes[1].contourf(Vmean[:].Time/24,znu,Vmean[:].transpose(),
             levels=np.linspace(-10,10,11),
             extend='both',
            cmap='PiYG')
im2 = axes[2].contourf(Tmean[:].Time/24,znu,Tmean[:].transpose(),
             levels=np.linspace(0,30,11),
             extend='both',
            cmap='PiYG')
fig.colorbar(im0,ax=axes[0])
fig.colorbar(im1,ax=axes[1])
fig.colorbar(im2,ax=axes[2])

titles = ['U','V','T','2m T']
for ii in range(4):
    axes[ii].set_title(titles[ii])
    axes[ii].set_xlabel('Time [Day]')

for ii in range(3):
    axes[ii].invert_yaxis()
    axes[ii].set_ylabel('Eta Level')

fig.savefig('plot_Var_timeseries_obs_Jan.png',format='png',dpi=400,bbox_inches='tight')

# %%
path = '/jet/home/xjliu/Amazon_exp/Tanguro201406/'
files = sorted(glob.glob(path+'3Dfields_d01_2014-06-*00:00:00'))

with xarray.open_dataset(files[0],decode_times=True,
                         mask_and_scale='True') as ds:
        Uall = ds['U'][:,:,5:-5,5:-5]
        T2all = ds['T2'][:,5:-5,5:-5]

for ii,filename in enumerate(files[1:30]):
    with xarray.open_dataset(filename,decode_times=True,
                         mask_and_scale='True') as ds:
        Uall = xarray.concat([Uall,ds['U'][:,:,5:-5,5:-5]],dim='Time')
        T2all = xarray.concat([T2all,ds['T2'][:,5:-5,5:-5]],dim='Time')
    print(ii,Uall.shape,filename)
# Out:
# 0 (48, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-02_00:00:00
# 1 (72, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-03_00:00:00
# 2 (96, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-04_00:00:00
# 3 (120, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-05_00:00:00
# 4 (144, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-06_00:00:00
# 5 (168, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-07_00:00:00
# 6 (192, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-08_00:00:00
# 7 (216, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-09_00:00:00
# 8 (240, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-10_00:00:00
# 9 (264, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-11_00:00:00
# 10 (288, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-12_00:00:00
# 11 (312, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-13_00:00:00
# 12 (336, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-14_00:00:00
# 13 (360, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-15_00:00:00
# 14 (384, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-16_00:00:00
# 15 (408, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-17_00:00:00
# 16 (432, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-18_00:00:00
# 17 (456, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-19_00:00:00
# 18 (480, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-20_00:00:00
# 19 (504, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-21_00:00:00
# 20 (528, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-22_00:00:00
# 21 (552, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-23_00:00:00
# 22 (576, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-24_00:00:00
# 23 (600, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-25_00:00:00
# 24 (624, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-26_00:00:00
# 25 (648, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-27_00:00:00
# 26 (672, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-28_00:00:00
# 27 (696, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-29_00:00:00
# 28 (720, 34, 70, 71) /jet/home/xjliu/Amazon_exp/Tanguro201406/3Dfields_d01_2014-06-30_00:00:00
